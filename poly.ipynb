# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from joblib import dump

# %%
X_train = pd.read_csv('../adv_mla_lab_4/data/processed/X_train.csv')
X_val   = pd.read_csv('../adv_mla_lab_4/data/processed/X_val.csv'  )
X_test  = pd.read_csv('../adv_mla_lab_4/data/processed/X_test.csv' )
y_train = pd.read_csv('../adv_mla_lab_4/data/processed/y_train.csv')
y_val   = pd.read_csv('../adv_mla_lab_4/data/processed/y_val.csv'  )
y_test  = pd.read_csv('../adv_mla_lab_4/data/processed/y_test.csv' )

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(2)

# %%
X_train = poly.fit_transform(X_train)

# %%
X_train.shape
# Out:
# (32000, 45)

# %%
X_val = poly.transform(X_val)
X_test = poly.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from joblib import dump

dump(reg,  '../adv_mla_lab_4/models/linear_poly_2.joblib')
# Out:
# ['../adv_mla_lab_4/models/linear_poly_2.joblib']

# %%
y_train_preds = reg.predict(X_train)
y_val_preds = reg.predict(X_val)

# %%
from sklearn.metrics import root_mean_squared_error as rmse
from sklearn.metrics import mean_absolute_error as mae

# %%
print(rmse(y_train_preds, y_train))
print(mae(y_train_preds, y_train))
# Out:
# 6109.188946937174
# 4091.517607223585

# %%
print(rmse(y_val_preds, y_val))
print(mae(y_val_preds, y_val))
# Out:
# 6105.041945227944
# 4088.8348532286086

# %%
y_test_preds = reg.predict(X_test)
print(rmse(y_test_preds, y_test))
print(mae(y_test_preds, y_test))
# Out:
# 6184.840436838625
# 4202.464943310798
